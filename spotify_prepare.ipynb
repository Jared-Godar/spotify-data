# %%
import pandas as pd
import numpy as np
import requests

# %% [markdown]
# ### Create streaming dataframe

# %%
# read your 1+ StreamingHistory files (depending on how extensive your streaming history is) into pandas dataframes
df_stream = pd.read_json('./MyData/StreamingHistory0.json')
#df_stream1 = pd.read_json('\MyData\streamingHistory1.json')

# merge streaming dataframes
#df_stream = pd.concat([df_stream0, df_stream1])

# create a 'UniqueID' for each song by combining the fields 'artistName' and 'trackName'
df_stream['UniqueID'] = df_stream['artistName'] + ":" + df_stream['trackName']

df_stream.head()
# Out:
#             endTime           artistName  \
# 0  2021-03-15 14:04           Crocodiles
# 1  2021-03-15 15:09  Global News Podcast
# 2  2021-03-15 15:09         Conor Oberst
# 3  2021-03-15 15:50  Global News Podcast
# 4  2021-03-15 16:21  Global News Podcast
#
#                                    trackName  msPlayed  \
# 0  Groove Is in the Heart / California Girls       682
# 1      Myanmar: Protesters killed in clashes      5674
# 2                           A Little Uncanny    124778
# 3      Myanmar: Protesters killed in clashes   1622749
# 4      Myanmar: Protesters killed in clashes      9813
#
#                                             UniqueID
# 0  Crocodiles:Groove Is in the Heart / California...
# 1  Global News Podcast:Myanmar: Protesters killed...
# 2                      Conor Oberst:A Little Uncanny
# 3  Global News Podcast:Myanmar: Protesters killed...
# 4  Global News Podcast:Myanmar: Protesters killed...

# %%
import json
from pandas.io.json import json_normalize

# %% [markdown]
# ### Create library Dataframe

# %%
with open('./MyData/YourLibrary.json') as json_data:
    data = json.load(json_data)

df_library = pd.DataFrame(data['tracks'])

# %%
# add UniqueID column (same as above)
df_library['UniqueID'] = df_library['artist'] + ":" + df_library['track']

# add column with track URI stripped of 'spotify:track:'
new = df_library["uri"].str.split(":", expand = True)
df_library['track_uri'] = new[2]

df_library.head()
# Out:
#             artist                               album  \
# 0  Johannes Brahms  Brahms: Hungarian Dances Nos. 1-21
# 1     Jason Isbell                        Southeastern
# 2      Steve Poltz                Live at the Belly Up
# 3    Chris Smither                       Call Me Lucky
# 4      Melody Pool              Deep Dark Savage Heart
#
#                                                track  \
# 0  21 Hungarian Dances, WoO 1 (version for orches...
# 1                                           Live Oak
# 2                        Kickin It Old School (Live)
# 3                                   Change Your Mind
# 4                                Southern Nightshade
#
#                                     uri  \
# 0  spotify:track:1e7uZfAoweDFcfrYVuifyk
# 1  spotify:track:51JJuDBT4n2bgVasYgkBjD
# 2  spotify:track:0mqcMV0qClE0p5hY7HqlT6
# 3  spotify:track:4tuWzu4mEMA2p0PPekTCpH
# 4  spotify:track:3nsW6nibHc3BtTblWF5EE0
#
#                                             UniqueID               track_uri
# 0  Johannes Brahms:21 Hungarian Dances, WoO 1 (ve...  1e7uZfAoweDFcfrYVuifyk
# 1                              Jason Isbell:Live Oak  51JJuDBT4n2bgVasYgkBjD
# 2            Steve Poltz:Kickin It Old School (Live)  0mqcMV0qClE0p5hY7HqlT6
# 3                     Chris Smither:Change Your Mind  4tuWzu4mEMA2p0PPekTCpH
# 4                    Melody Pool:Southern Nightshade  3nsW6nibHc3BtTblWF5EE0

# %%
# create final dict as a copy df_stream
df_tableau = df_stream.copy()

# add column checking if streamed song is in library
# not used in this project but could be helpful for cool visualizations
df_tableau['In Library'] = np.where(df_tableau['UniqueID'].isin(df_library['UniqueID'].tolist()),1,0)

# left join with df_library on UniqueID to bring in album and track_uri
df_tableau = pd.merge(df_tableau, df_library[['album','UniqueID','track_uri']],how='left',on=['UniqueID'])

df_tableau.head()
# Out:
#             endTime           artistName  \
# 0  2021-03-15 14:04           Crocodiles
# 1  2021-03-15 15:09  Global News Podcast
# 2  2021-03-15 15:09         Conor Oberst
# 3  2021-03-15 15:50  Global News Podcast
# 4  2021-03-15 16:21  Global News Podcast
#
#                                    trackName  msPlayed  \
# 0  Groove Is in the Heart / California Girls       682
# 1      Myanmar: Protesters killed in clashes      5674
# 2                           A Little Uncanny    124778
# 3      Myanmar: Protesters killed in clashes   1622749
# 4      Myanmar: Protesters killed in clashes      9813
#
#                                             UniqueID  In Library album  \
# 0  Crocodiles:Groove Is in the Heart / California...           0   NaN
# 1  Global News Podcast:Myanmar: Protesters killed...           0   NaN
# 2                      Conor Oberst:A Little Uncanny           0   NaN
# 3  Global News Podcast:Myanmar: Protesters killed...           0   NaN
# 4  Global News Podcast:Myanmar: Protesters killed...           0   NaN
#
#   track_uri
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %% [markdown]
# ### Create Genre Dataframe

# %%
from env import CLIENT_ID, CLIENT_SECRET

# %%
# generate access token

# authentication URL
AUTH_URL = 'https://accounts.spotify.com/api/token'

# POST
auth_response = requests.post(AUTH_URL, {
    'grant_type': 'client_credentials',
    'client_id': CLIENT_ID,
    'client_secret': CLIENT_SECRET,
})

# convert the response to JSON
auth_response_data = auth_response.json()

# save the access token
access_token = auth_response_data['access_token']

# %%
# used for authenticating all API calls
headers = {'Authorization': 'Bearer {token}'.format(token=access_token)}

# %%
# base URL of all Spotify API endpoints
BASE_URL = 'https://api.spotify.com/v1/'

# %%
# create blank dictionary to store track URI, artist URI, and genres
dict_genre = {}

# convert track_uri column to an iterable list
track_uris = df_library['track_uri'].to_list()

# loop through track URIs and pull artist URI using the API,
# then use artist URI to pull genres associated with that artist
# store all these in a dictionary
for t_uri in track_uris:
    
    dict_genre[t_uri] = {'artist_uri': "", "genres":[]}
    
    r = requests.get(BASE_URL + 'tracks/' + t_uri, headers=headers)
    r = r.json()
    a_uri = r['artists'][0]['uri'].split(':')[2]
    dict_genre[t_uri]['artist_uri'] = a_uri
    
    s = requests.get(BASE_URL + 'artists/' + a_uri, headers=headers)
    s = s.json()
    dict_genre[t_uri]['genres'] = s['genres']
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/9y/17ptyrds267724n2_7s7hx340000gn/T/ipykernel_41183/664100588.py in <module>
#      17     dict_genre[t_uri]['artist_uri'] = a_uri
#      18
# ---> 19     s = requests.get(BASE_URL + 'artists/' + a_uri, headers=headers)
#      20     s = s.json()
#      21     dict_genre[t_uri]['genres'] = s['genres']
#
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# /opt/homebrew/anaconda3/lib/python3.8/http/client.py in getresponse(self)
#    1346         try:
#    1347             try:
# -> 1348                 response.begin()
#    1349             except ConnectionError:
#    1350                 self.close()
#
# /opt/homebrew/anaconda3/lib/python3.8/http/client.py in begin(self)
#     314         # read until we get a non-100 response
#     315         while True:
# --> 316             version, status, reason = self._read_status()
#     317             if status != CONTINUE:
#     318                 break
#
# /opt/homebrew/anaconda3/lib/python3.8/http/client.py in _read_status(self)
#     275
#     276     def _read_status(self):
# --> 277         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278         if len(line) > _MAXLINE:
#     279             raise LineTooLong("status line")
#
# /opt/homebrew/anaconda3/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# /opt/homebrew/anaconda3/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# /opt/homebrew/anaconda3/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# convert dictionary into dataframe with track_uri as the first column
df_genre = pd.DataFrame.from_dict(dict_genre, orient='index')
df_genre.insert(0, 'track_uri', df_genre.index)
df_genre.reset_index(inplace=True, drop=True)

df_genre.head()

# %%
df_genre_expanded = df_genre.explode('genres')
df_genre_expanded.head()

# %%
# save df_tableau and df_genre_expanded as csv files that we can load into Tableau
df_tableau.to_csv('MySpotifyDataTable.csv')
df_genre_expanded.to_csv('GenresExpandedTable.csv')

print('done')

# %% [markdown]
# ---

# %%
pd.set_option('max_colwidth', 400)

# %%
#Bring in wranGgled data
df_tableau = pd.read_csv('MySpotifyDataTable.csv')
df_genre_expanded = pd.read_csv('GenresExpandedTable.csv')

# %%
df_tableau.tail()
# Out:
#       Unnamed: 0           endTime           artistName  \
# 8052        8052  2022-03-14 03:47           Miko Marks
# 8053        8053  2022-03-14 03:47       Chicago Farmer
# 8054        8054  2022-03-14 12:51  Global News Podcast
# 8055        8055  2022-03-14 13:21  Global News Podcast
# 8056        8056  2022-03-14 13:25       Chicago Farmer
#
#                                                 trackName  msPlayed  \
# 8052                                    Long Journey Home    187255
# 8053                                            $13 Beers     10710
# 8054  Russia strikes Ukraine army base near Polish border      4544
# 8055  Russia strikes Ukraine army base near Polish border   1761543
# 8056                                            $13 Beers    198245
#
#                                                                      UniqueID  \
# 8052                                             Miko Marks:Long Journey Home
# 8053                                                 Chicago Farmer:$13 Beers
# 8054  Global News Podcast:Russia strikes Ukraine army base near Polish border
# 8055  Global News Podcast:Russia strikes Ukraine army base near Polish border
# 8056                                                 Chicago Farmer:$13 Beers
#
#       In Library album track_uri  minPlayed
# 8052           0   NaN       NaN   3.120917
# 8053           0   NaN       NaN   0.178500
# 8054           0   NaN       NaN   0.075733
# 8055           0   NaN       NaN  29.359050
# 8056           0   NaN       NaN   3.304083

# %%
df_genre_expanded.head(100)
# Out:
#     Unnamed: 0               track_uri              artist_uri  \
# 0            0  1e7uZfAoweDFcfrYVuifyk  5wTAi7QkpP6kp8a54lmTOq
# 1            0  1e7uZfAoweDFcfrYVuifyk  5wTAi7QkpP6kp8a54lmTOq
# 2            0  1e7uZfAoweDFcfrYVuifyk  5wTAi7QkpP6kp8a54lmTOq
# 3            1  51JJuDBT4n2bgVasYgkBjD  3Q8wgwyVVv0z4UEh1HB0KY
# 4            1  51JJuDBT4n2bgVasYgkBjD  3Q8wgwyVVv0z4UEh1HB0KY
# ..         ...                     ...                     ...
# 95          17  7qbv4GNE6rFpYe78BIcu4v  3ZWab2LEVkNKiBPIClTwof
# 96          17  7qbv4GNE6rFpYe78BIcu4v  3ZWab2LEVkNKiBPIClTwof
# 97          17  7qbv4GNE6rFpYe78BIcu4v  3ZWab2LEVkNKiBPIClTwof
# 98          18  2IB4JNfzBCtL4OL4PuHV88  0nJUwPwC9Ti4vvuJ0q3MfT
# 99          18  2IB4JNfzBCtL4OL4PuHV88  0nJUwPwC9Ti4vvuJ0q3MfT
#
#                  genres
# 0             classical
# 1    german romanticism
# 2     late romantic era
# 3   alternative country
# 4                  folk
# ..                  ...
# 95           roots rock
# 96    singer-songwriter
# 97        texas country
# 98  alternative country
# 99         country rock
#
# [100 rows x 4 columns]

# %% [markdown]
# ---

# %% [markdown]
# ### Get rid of podcasts
#
# When looking at the viz, podcasts are disproportionately represented by their length. Find a feature to filter them out and re-export

# %%
df_tableau[df_tableau['artistName'].str.contains('Podcast')]
# Out:
#       Unnamed: 0           endTime           artistName  \
# 1              1  2021-03-15 15:09  Global News Podcast
# 3              3  2021-03-15 15:50  Global News Podcast
# 4              4  2021-03-15 16:21  Global News Podcast
# 5              5  2021-03-15 16:26  Global News Podcast
# 12            12  2021-03-16 16:08  Global News Podcast
# ...          ...               ...                  ...
# 7897        7897  2022-03-09 15:30  Global News Podcast
# 7898        7898  2022-03-09 18:42  Global News Podcast
# 7997        7997  2022-03-11 19:26  Global News Podcast
# 8054        8054  2022-03-14 12:51  Global News Podcast
# 8055        8055  2022-03-14 13:21  Global News Podcast
#
#                                                           trackName  msPlayed  \
# 1                             Myanmar: Protesters killed in clashes      5674
# 3                             Myanmar: Protesters killed in clashes   1622749
# 4                             Myanmar: Protesters killed in clashes      9813
# 5                             Myanmar: Protesters killed in clashes    283847
# 12                        Mozambique militants 'beheading children'     25671
# ...                                                             ...       ...
# 7897  Zelensky vows to fight Russia in 'forests, fields and shores'   1038458
# 7898  Zelensky vows to fight Russia in 'forests, fields and shores'    907520
# 7997              Ukraine: Mariupol 'running out of food and water'   1804027
# 8054            Russia strikes Ukraine army base near Polish border      4544
# 8055            Russia strikes Ukraine army base near Polish border   1761543
#
#                                                                                UniqueID  \
# 1                             Global News Podcast:Myanmar: Protesters killed in clashes
# 3                             Global News Podcast:Myanmar: Protesters killed in clashes
# 4                             Global News Podcast:Myanmar: Protesters killed in clashes
# 5                             Global News Podcast:Myanmar: Protesters killed in clashes
# 12                        Global News Podcast:Mozambique militants 'beheading children'
# ...                                                                                 ...
# 7897  Global News Podcast:Zelensky vows to fight Russia in 'forests, fields and shores'
# 7898  Global News Podcast:Zelensky vows to fight Russia in 'forests, fields and shores'
# 7997              Global News Podcast:Ukraine: Mariupol 'running out of food and water'
# 8054            Global News Podcast:Russia strikes Ukraine army base near Polish border
# 8055            Global News Podcast:Russia strikes Ukraine army base near Polish border
#
#       In Library album track_uri
# 1              0   NaN       NaN
# 3              0   NaN       NaN
# 4              0   NaN       NaN
# 5              0   NaN       NaN
# 12             0   NaN       NaN
# ...          ...   ...       ...
# 7897           0   NaN       NaN
# 7898           0   NaN       NaN
# 7997           0   NaN       NaN
# 8054           0   NaN       NaN
# 8055           0   NaN       NaN
#
# [512 rows x 9 columns]

# %%
df_tableau['minPlayed']=df_tableau.msPlayed/60000

# %% [markdown]
# Try filtering by song length. >10 min for podcasts - steve poltz live filtered out. Changed to 11 - lost emma smith sad eyed lady of the lowlands... Changed to 12 - still losing some rimsky-kosakov, stravinski, and other classical, but it is an improvement
#
# - No keywords in the track or artist name for easy filtering - was hoping a genre merge would help
#
# no track_uri or album for podcast, but that could be the answer

# %%
pd.set_option('display.max_rows', 100)

# %%
df_tableau[df_tableau['minPlayed']>12]
# Out:
#       Unnamed: 0           endTime           artistName  \
# 3              3  2021-03-15 15:50  Global News Podcast
# 15            15  2021-03-16 16:39  Global News Podcast
# 16            16  2021-03-16 17:08  Global News Podcast
# 17            17  2021-03-16 17:25  Global News Podcast
# 21            21  2021-03-18 14:45  Global News Podcast
# ...          ...               ...                  ...
# 7725        7725  2022-03-01 18:34             Up First
# 7897        7897  2022-03-09 15:30  Global News Podcast
# 7898        7898  2022-03-09 18:42  Global News Podcast
# 7997        7997  2022-03-11 19:26  Global News Podcast
# 8055        8055  2022-03-14 13:21  Global News Podcast
#
#                                                           trackName  msPlayed  \
# 3                             Myanmar: Protesters killed in clashes   1622749
# 15                        Mozambique militants 'beheading children'   1814043
# 16         Myanmar military continues its suppression of protesters   1653390
# 17                      Minneapolis to pay George Floyd family $27m   1048608
# 21             Russia recalls envoy after Biden remarks about Putin   1705039
# ...                                                             ...       ...
# 7725                                         Tuesday, March 1, 2022    761927
# 7897  Zelensky vows to fight Russia in 'forests, fields and shores'   1038458
# 7898  Zelensky vows to fight Russia in 'forests, fields and shores'    907520
# 7997              Ukraine: Mariupol 'running out of food and water'   1804027
# 8055            Russia strikes Ukraine army base near Polish border   1761543
#
#                                                                                UniqueID  \
# 3                             Global News Podcast:Myanmar: Protesters killed in clashes
# 15                        Global News Podcast:Mozambique militants 'beheading children'
# 16         Global News Podcast:Myanmar military continues its suppression of protesters
# 17                      Global News Podcast:Minneapolis to pay George Floyd family $27m
# 21             Global News Podcast:Russia recalls envoy after Biden remarks about Putin
# ...                                                                                 ...
# 7725                                                    Up First:Tuesday, March 1, 2022
# 7897  Global News Podcast:Zelensky vows to fight Russia in 'forests, fields and shores'
# 7898  Global News Podcast:Zelensky vows to fight Russia in 'forests, fields and shores'
# 7997              Global News Podcast:Ukraine: Mariupol 'running out of food and water'
# 8055            Global News Podcast:Russia strikes Ukraine army base near Polish border
#
#       In Library album track_uri  minPlayed
# 3              0   NaN       NaN  27.045817
# 15             0   NaN       NaN  30.234050
# 16             0   NaN       NaN  27.556500
# 17             0   NaN       NaN  17.476800
# 21             0   NaN       NaN  28.417317
# ...          ...   ...       ...        ...
# 7725           0   NaN       NaN  12.698783
# 7897           0   NaN       NaN  17.307633
# 7898           0   NaN       NaN  15.125333
# 7997           0   NaN       NaN  30.067117
# 8055           0   NaN       NaN  29.359050
#
# [394 rows x 10 columns]

# %%
df_tableau[df_tableau['track_uri'].isnull()]
# Out:
#       Unnamed: 0           endTime           artistName  \
# 0              0  2021-03-15 14:04           Crocodiles
# 1              1  2021-03-15 15:09  Global News Podcast
# 2              2  2021-03-15 15:09         Conor Oberst
# 3              3  2021-03-15 15:50  Global News Podcast
# 4              4  2021-03-15 16:21  Global News Podcast
# ...          ...               ...                  ...
# 8052        8052  2022-03-14 03:47           Miko Marks
# 8053        8053  2022-03-14 03:47       Chicago Farmer
# 8054        8054  2022-03-14 12:51  Global News Podcast
# 8055        8055  2022-03-14 13:21  Global News Podcast
# 8056        8056  2022-03-14 13:25       Chicago Farmer
#
#                                                 trackName  msPlayed  \
# 0               Groove Is in the Heart / California Girls       682
# 1                   Myanmar: Protesters killed in clashes      5674
# 2                                        A Little Uncanny    124778
# 3                   Myanmar: Protesters killed in clashes   1622749
# 4                   Myanmar: Protesters killed in clashes      9813
# ...                                                   ...       ...
# 8052                                    Long Journey Home    187255
# 8053                                            $13 Beers     10710
# 8054  Russia strikes Ukraine army base near Polish border      4544
# 8055  Russia strikes Ukraine army base near Polish border   1761543
# 8056                                            $13 Beers    198245
#
#                                                                      UniqueID  \
# 0                        Crocodiles:Groove Is in the Heart / California Girls
# 1                   Global News Podcast:Myanmar: Protesters killed in clashes
# 2                                               Conor Oberst:A Little Uncanny
# 3                   Global News Podcast:Myanmar: Protesters killed in clashes
# 4                   Global News Podcast:Myanmar: Protesters killed in clashes
# ...                                                                       ...
# 8052                                             Miko Marks:Long Journey Home
# 8053                                                 Chicago Farmer:$13 Beers
# 8054  Global News Podcast:Russia strikes Ukraine army base near Polish border
# 8055  Global News Podcast:Russia strikes Ukraine army base near Polish border
# 8056                                                 Chicago Farmer:$13 Beers
#
#       In Library album track_uri  minPlayed
# 0              0   NaN       NaN   0.011367
# 1              0   NaN       NaN   0.094567
# 2              0   NaN       NaN   2.079633
# 3              0   NaN       NaN  27.045817
# 4              0   NaN       NaN   0.163550
# ...          ...   ...       ...        ...
# 8052           0   NaN       NaN   3.120917
# 8053           0   NaN       NaN   0.178500
# 8054           0   NaN       NaN   0.075733
# 8055           0   NaN       NaN  29.359050
# 8056           0   NaN       NaN   3.304083
#
# [6411 rows x 10 columns]

# %% [markdown]
# Null search gives 6411 rows including lots of podcasts, but apparently also songs
